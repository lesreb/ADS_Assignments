# %%
import pandas as pd
import plotly.express as px
import numpy as np

# %%
#gapminder_df =  px.data.gapminder()

# %%
gapminder_df =  pd.DataFrame(px.data.gapminder())

# %%
gapminder_df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
gapminder_df.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap',
#        'iso_alpha', 'iso_num'],
#       dtype='object')

# %%
gapminder_df.dtypes
# Out:
# country       object
# continent     object
# year           int64
# lifeExp      float64
# pop            int64
# gdpPercap    float64
# iso_alpha     object
# iso_num        int64
# dtype: object

# %% [markdown]
# 1. The mean life expectancy of all the Asian countries according to the data.

# %%
gapminder_df.shape
# Out:
# (1704, 8)

# %%
gapminder_df.get('continent').value_counts()
# Out:
# Africa      624
# Asia        396
# Europe      360
# Americas    300
# Oceania      24
# Name: continent, dtype: int64

# %%
1. The mean life expectancy of all the Asian countries according to the data
# Out:
#   File "<ipython-input-251-a7b5954e7f87>", line 1
#     1. The mean life expectancy of all the Asian countries according to the data
#        ^
# SyntaxError: invalid syntax

# %%
asia_df=gapminder_df.query("continent =='Asia'")

fig = px.choropleth(asia_df,locations='iso_alpha',
                   color='lifeExp', hover_name='country',
                   color_continuous_scale=px.colors.sequential.matter)

fig.show()
# Out:
# <div>                            <div id="bff24117-0cdc-4144-9971-a13ea1738001" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bff24117-0cdc-4144-9971-a13ea1738001")) {                    Plotly.newPlot(                        "bff24117-0cdc-4144-9971-a13ea1738001",                        [{"coloraxis": "coloraxis", "geo": "geo", "hovertemplate": "<b>%{hovertext}</b><br><br>iso_alpha=%{location}<br>lifeExp=%{z}<extra></extra>", "hovertext": ["Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", "Bahrain", 
# ...

# %%
europe_america_df=gapminder_df.query("continent == 'Europe' or continent == 'Americas'")
europe_america_df
# Out:
#         country continent  year  lifeExp       pop     gdpPercap iso_alpha  \
# 12      Albania    Europe  1952   55.230   1282697   1601.056136       ALB
# 13      Albania    Europe  1957   59.280   1476505   1942.284244       ALB
# 14      Albania    Europe  1962   64.820   1728137   2312.888958       ALB
# 15      Albania    Europe  1967   66.220   1984060   2760.196931       ALB
# 16      Albania    Europe  1972   67.690   2263554   3313.422188       ALB
# ...         ...       ...   ...      ...       ...           ...       ...
# 1639  Venezuela  Americas  1987   70.190  17910182   9883.584648       VEN
# 1640  Venezuela  Americas  1992   71.150  20265563  10733.926310       VEN
# 1641  Venezuela  Americas  1997   72.146  22374398  10165.495180       VEN
# 1642  Venezuela  Americas  2002   72.766  24287670   8605.047831       VEN
# 1643  Venezuela  Americas  2007   73.747  26084662  11415.805690       VEN
#
#       iso_num
# 12          8
# 13          8
# 14          8
# ...

# %% [markdown]
# 2. Deviation in GDP of each country in Europe and South America.

# %%
fig = px.choropleth(europe_america_df,locations='iso_alpha',
                   color='gdpPercap', hover_name='country',
                   color_continuous_scale=px.colors.sequential.matter)

fig.show()
# Out:
# <div>                            <div id="36589996-2d56-4bff-b5e2-6c8afbbeb7e3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("36589996-2d56-4bff-b5e2-6c8afbbeb7e3")) {                    Plotly.newPlot(                        "36589996-2d56-4bff-b5e2-6c8afbbeb7e3",                        [{"coloraxis": "coloraxis", "geo": "geo", "hovertemplate": "<b>%{hovertext}</b><br><br>iso_alpha=%{location}<br>gdpPercap=%{z}<extra></extra>", "hovertext": ["Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Argentina", "Argentina", "Argentina", "Argentina", "Argentina", "Argentina", "Argentina", "Argentina", "Argentina", "Argentina", "Argentina", "Argentina", "Austria", "Austria", 
# ...

# %%
europe_df=gapminder_df.query("continent =='Europe'")

fig = px.choropleth(europe_america_df,locations='iso_alpha',
                   color='gdpPercap', hover_name='country',
                   color_continuous_scale=px.colors.sequential.matter)

fig.show()
# Out:
# <div>                            <div id="21634b9c-ac10-45b4-9696-da75877863d8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("21634b9c-ac10-45b4-9696-da75877863d8")) {                    Plotly.newPlot(                        "21634b9c-ac10-45b4-9696-da75877863d8",                        [{"coloraxis": "coloraxis", "geo": "geo", "hovertemplate": "<b>%{hovertext}</b><br><br>iso_alpha=%{location}<br>gdpPercap=%{z}<extra></extra>", "hovertext": ["Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Austria", "Austria", "Austria", "Austria", "Austria", "Austria", "Austria", "Austria", "Austria", "Austria", "Austria", "Austria", "Belgium", "Belgium", "Belgium", "Belgium", "B
# ...

# %%
fig = px.choropleth(gapminder_df,locations='iso_alpha',
                   color='gdpPercap', hover_name='country',
                   color_continuous_scale=px.colors.sequential.matter,
                   scope="south america")

fig.show()
# Out:
# <div>                            <div id="18c5eb9b-6587-4019-8411-fdea97c594a2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("18c5eb9b-6587-4019-8411-fdea97c594a2")) {                    Plotly.newPlot(                        "18c5eb9b-6587-4019-8411-fdea97c594a2",                        [{"coloraxis": "coloraxis", "geo": "geo", "hovertemplate": "<b>%{hovertext}</b><br><br>iso_alpha=%{location}<br>gdpPercap=%{z}<extra></extra>", "hovertext": ["Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Afghanistan", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania", "Albania"
# ...

# %% [markdown]
# 3. The change in population of each African country in the last 3 decades.

# %%
africa_df = gapminder_df.query("year >= 1991" and "year < 2021" and "continent == 'Africa'")
africa_df
# Out:
#        country continent  year  lifeExp       pop    gdpPercap iso_alpha  \
# 24     Algeria    Africa  1952   43.077   9279525  2449.008185       DZA
# 25     Algeria    Africa  1957   45.685  10270856  3013.976023       DZA
# 26     Algeria    Africa  1962   48.303  11000948  2550.816880       DZA
# 27     Algeria    Africa  1967   51.407  12760499  3246.991771       DZA
# 28     Algeria    Africa  1972   54.518  14760787  4182.663766       DZA
# ...        ...       ...   ...      ...       ...          ...       ...
# 1699  Zimbabwe    Africa  1987   62.351   9216418   706.157306       ZWE
# 1700  Zimbabwe    Africa  1992   60.377  10704340   693.420786       ZWE
# 1701  Zimbabwe    Africa  1997   46.809  11404948   792.449960       ZWE
# 1702  Zimbabwe    Africa  2002   39.989  11926563   672.038623       ZWE
# 1703  Zimbabwe    Africa  2007   43.487  12311143   469.709298       ZWE
#
#       iso_num
# 24         12
# 25         12
# 26         12
# 27         12
# ...

# %%
africa_df.dtypes
# Out:
# country       object
# continent     object
# year           int64
# lifeExp      float64
# pop            int64
# gdpPercap    float64
# iso_alpha     object
# iso_num        int64
# dtype: object

# %%
africa_df['year_min_diff'] = africa_df['year'] - 1991
# Out:
# <ipython-input-230-811ac8d1410a>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
africa_df
# Out:
#        country continent  year  lifeExp       pop    gdpPercap iso_alpha  \
# 24     Algeria    Africa  1952   43.077   9279525  2449.008185       DZA
# 25     Algeria    Africa  1957   45.685  10270856  3013.976023       DZA
# 26     Algeria    Africa  1962   48.303  11000948  2550.816880       DZA
# 27     Algeria    Africa  1967   51.407  12760499  3246.991771       DZA
# 28     Algeria    Africa  1972   54.518  14760787  4182.663766       DZA
# ...        ...       ...   ...      ...       ...          ...       ...
# 1699  Zimbabwe    Africa  1987   62.351   9216418   706.157306       ZWE
# 1700  Zimbabwe    Africa  1992   60.377  10704340   693.420786       ZWE
# 1701  Zimbabwe    Africa  1997   46.809  11404948   792.449960       ZWE
# 1702  Zimbabwe    Africa  2002   39.989  11926563   672.038623       ZWE
# 1703  Zimbabwe    Africa  2007   43.487  12311143   469.709298       ZWE
#
#       iso_num  year_min_diff
# 24         12            -39
# 25         12            -34
# ...

# %%
#drop rows with data more than three decades (before year 1991)
africa_df_after_91 = africa_df[africa_df['year_min_diff'] >= 0]
africa_df_after_91
# Out:
#        country continent  year  lifeExp       pop    gdpPercap iso_alpha  \
# 32     Algeria    Africa  1992   67.744  26298373  5023.216647       DZA
# 33     Algeria    Africa  1997   69.152  29072015  4797.295051       DZA
# 34     Algeria    Africa  2002   70.994  31287142  5288.040382       DZA
# 35     Algeria    Africa  2007   72.301  33333216  6223.367465       DZA
# 44      Angola    Africa  1992   40.647   8735988  2627.845685       AGO
# ...        ...       ...   ...      ...       ...          ...       ...
# 1691    Zambia    Africa  2007   42.384  11746035  1271.211593       ZMB
# 1700  Zimbabwe    Africa  1992   60.377  10704340   693.420786       ZWE
# 1701  Zimbabwe    Africa  1997   46.809  11404948   792.449960       ZWE
# 1702  Zimbabwe    Africa  2002   39.989  11926563   672.038623       ZWE
# 1703  Zimbabwe    Africa  2007   43.487  12311143   469.709298       ZWE
#
#       iso_num  year_min_diff
# 32         12              1
# 33         12              6
# ...

# %%
#recent year for each African country
africa_df_after_91['recent_year'] = 2007 - africa_df['year']
# Out:
# <ipython-input-241-74d761bb068d>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#for each country, choose the row with minimum year_min_diff (earliest in last 3 decades) 
#and minimum recent_year (most recent year), minimum diff = 1 --> minimum year = 1992.
#Minimum recent year diff ==0 ----> maximum year == 2007

africa_1992=africa_df_after_91[africa_df_after_91['year_min_diff']==1]
africa_1992.index=np.arange(0,len(africa_1992))
africa_1992
# Out:
#                      country continent  year  lifeExp       pop     gdpPercap  \
# 0                    Algeria    Africa  1992   67.744  26298373   5023.216647
# 1                     Angola    Africa  1992   40.647   8735988   2627.845685
# 2                      Benin    Africa  1992   53.919   4981671   1191.207681
# 3                   Botswana    Africa  1992   62.745   1342614   7954.111645
# 4               Burkina Faso    Africa  1992   50.260   8878303    931.752773
# 5                    Burundi    Africa  1992   44.736   5809236    631.699878
# 6                   Cameroon    Africa  1992   54.314  12467171   1793.163278
# 7   Central African Republic    Africa  1992   49.396   3265124    747.905525
# 8                       Chad    Africa  1992   51.724   6429417   1058.064300
# 9                    Comoros    Africa  1992   57.939    454429   1246.907370
# 10          Congo, Dem. Rep.    Africa  1992   45.548  41672143    457.719181
# ...

# %%
africa_2007=africa_df_after_91[africa_df_after_91['recent_year']==0]
africa_2007.index=np.arange(0,len(africa_2007))
africa_2007
# Out:
#                      country continent  year  lifeExp        pop  \
# 0                    Algeria    Africa  2007   72.301   33333216
# 1                     Angola    Africa  2007   42.731   12420476
# 2                      Benin    Africa  2007   56.728    8078314
# 3                   Botswana    Africa  2007   50.728    1639131
# 4               Burkina Faso    Africa  2007   52.295   14326203
# 5                    Burundi    Africa  2007   49.580    8390505
# 6                   Cameroon    Africa  2007   50.430   17696293
# 7   Central African Republic    Africa  2007   44.741    4369038
# 8                       Chad    Africa  2007   50.651   10238807
# 9                    Comoros    Africa  2007   65.152     710960
# 10          Congo, Dem. Rep.    Africa  2007   46.462   64606759
# 11               Congo, Rep.    Africa  2007   55.322    3800610
# 12             Cote d'Ivoire    Africa  2007   48.328   18013409
# ...

# %%
africa_2007['pop_diff'] = africa_2007['pop'] - africa_1992['pop']
# Out:
# <ipython-input-246-b56b0fd4e763>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#africa_2007.index=np.arange(0,len(africa_2007))
africa_2007
# Out:
#                      country continent  year  lifeExp        pop  \
# 0                    Algeria    Africa  2007   72.301   33333216
# 1                     Angola    Africa  2007   42.731   12420476
# 2                      Benin    Africa  2007   56.728    8078314
# 3                   Botswana    Africa  2007   50.728    1639131
# 4               Burkina Faso    Africa  2007   52.295   14326203
# 5                    Burundi    Africa  2007   49.580    8390505
# 6                   Cameroon    Africa  2007   50.430   17696293
# 7   Central African Republic    Africa  2007   44.741    4369038
# 8                       Chad    Africa  2007   50.651   10238807
# 9                    Comoros    Africa  2007   65.152     710960
# 10          Congo, Dem. Rep.    Africa  2007   46.462   64606759
# 11               Congo, Rep.    Africa  2007   55.322    3800610
# 12             Cote d'Ivoire    Africa  2007   48.328   18013409
# ...

# %%
africa_2007.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap',
#        'iso_alpha', 'iso_num', 'year_min_diff', 'recent_year', 'pop_diff'],
#       dtype='object')

# %%
fig = px.choropleth(africa_2007,locations='iso_alpha',
                   color='pop_diff', hover_name='country',
                   color_continuous_scale=px.colors.sequential.matter)

fig.show()
# Out:
# <div>                            <div id="34bbbe25-67e7-4dec-a31a-11105ed3bb07" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("34bbbe25-67e7-4dec-a31a-11105ed3bb07")) {                    Plotly.newPlot(                        "34bbbe25-67e7-4dec-a31a-11105ed3bb07",                        [{"coloraxis": "coloraxis", "geo": "geo", "hovertemplate": "<b>%{hovertext}</b><br><br>iso_alpha=%{location}<br>pop_diff=%{z}<extra></extra>", "hovertext": ["Algeria", "Angola", "Benin", "Botswana", "Burkina Faso", "Burundi", "Cameroon", "Central African Republic", "Chad", "Comoros", "Congo, Dem. Rep.", "Congo, Rep.", "Cote d'Ivoire", "Djibouti", "Egypt", "Equatorial Guinea", "Eritrea", "Ethiopia", "Gabon", "Gambia", "Ghana", "Guinea", "Guinea-Bissau", "Kenya", "L
# ...
